# %%
import os
os.chdir(r"C:\Users\senya\Downloads\russian-power-network-main (2)\russian-power-network-main")
os.getcwd()
# Out:
# 'C:\\Users\\senya\\Downloads\\russian-power-network-main (2)\\russian-power-network-main'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data',
#  'docs',
#  'notebooks',
#  'outputs',
#  'README.md',
#  'report',
#  'requirements.txt',
#  'scripts',
#  'src',
#  'Untitled.ipynb',
#  'untitled.py']

# %%
# !python scripts/run_analysis.py
# Out:
# Done.
# Nodes: 522 Edges: 1920
# Official snapshot rows: 15

# %%
import os
os.listdir("outputs/figures")
# Out:
# ['core_network_top40.png',
#  'official_collection_counts.png',
#  'relations_by_layer.png',
#  'top15_core_degree.png']

# %%
from IPython.display import Image, display

display(Image(filename="outputs/figures/core_network_top40.png"))
display(Image(filename="outputs/figures/top15_core_degree.png"))
display(Image(filename="outputs/figures/relations_by_layer.png"))
display(Image(filename="outputs/figures/official_collection_counts.png"))

# %%
os.listdir("outputs/tables")
# Out:
# ['core_formal_centrality.csv',
#  'official_collection_summary.csv',
#  'official_snapshot.csv',
#  'relation_counts_by_layer.csv',
#  'summary_stats.csv']

# %%
import os
os.listdir("outputs/tables")
# Out:
# ['core_formal_centrality.csv',
#  'official_collection_summary.csv',
#  'official_snapshot.csv',
#  'relation_counts_by_layer.csv',
#  'summary_stats.csv']

# %%
import pandas as pd
pd.read_csv("outputs/tables/summary_stats.csv")
# Out:
#    nodes_total  edges_total  comention_nodes  core_nodes  overlay_nodes  \
# 0          522         1920              110         282            130
#
#    comention_edges  core_edges  overlay_edges
# 0             1422         448             50

# %%
pd.read_csv("outputs/tables/relation_counts_by_layer.csv")
# Out:
#         layer                    type  count
# 0   comention            соупоминание   1313
# 1   comention   упоминание_источником    109
# 2        core                contains    126
# 3        core      занимает_должность    102
# 4        core         контроль_надзор      7
# 5        core             координация      8
# 6        core              назначение    118
# 7        core  неформальное_отношение     12
# 8        core              подчинение     75
# 9     overlay                contains      4
# 10    overlay      занимает_должность     37
# 11    overlay  неформальное_отношение      9
